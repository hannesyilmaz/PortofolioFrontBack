# %%
import feedparser
import sys
import pyodbc
import requests
import requests_toolbelt

RSS_URLS = ['http://www.dn.se/nyheter/m/rss/',
            'https://rss.aftonbladet.se/rss2/small/pages/sections/senastenytt/', 'https://feeds.expressen.se/nyheter/',
            'http://www.svd.se/?service=rss', 'http://api.sr.se/api/rss/program/83?format=145',
            'http://www.svt.se/nyheter/rss.xml'
              ]

posts = []

for url in RSS_URLS:
    posts.extend(feedparser.parse(url).entries)

def OnlyTitlesandSumaries():
    only_titles_and_summaries = []
    for x in posts:
        try:
            tempdict = {}
            tempdict["title"] = x["title"]
            tempdict["summary"] = x["summary"]
            only_titles_and_summaries.append(tempdict)
        except KeyError as ke:
            only_titles_and_summaries.append("") #replace the missing keys with empty space
    return only_titles_and_summaries

Only_the_titles_Summaries = OnlyTitlesandSumaries()

print(Only_the_titles_Summaries)
print(len(Only_the_titles_Summaries))

def TitleAndSummaryList():
    title_and_summary_list = []
    temp_and_summary_title_list = []
    for x in Only_the_titles_Summaries:
        for key in x:
            if 'title' == key:
                firstkey = x[key]
            if 'summary' == key:
                secondkey = x[key]
                temp_and_summary_title_list.append(firstkey + ' ' + secondkey)
        title_and_summary_list.append(temp_and_summary_title_list)
        temp_and_summary_title_list = []
    return title_and_summary_list

The_Title_Summary_List = TitleAndSummaryList()

print(The_Title_Summary_List)
print(len(The_Title_Summary_List))

def PrintDeposit():
    newList= []
    for item in The_Title_Summary_List:
        for value in item:
            newList.append(value)
    return newList
# Out:
# [{'title': 'Hällristningar skadade i Norge', 'summary': ''}, {'title': 'Hammarby stänger av Mohanad Jeahze', 'summary': ''}, {'title': 'Jan Scherman: SR:s Cilla Benkö fortsätter sitt arroganta korståg', 'summary': ''}, {'title': 'Cilla Benkö: Flera utgångspunkter i DN:s granskning är missvisande', 'summary': ''}, {'title': 'Coronahalt i avloppen ökar igen', 'summary': ''}, {'title': 'Lindelöf får konkurrens – mittback presenterad', 'summary': ''}, {'title': 'Neymar inför rätta – nio år efter övergången', 'summary': ''}, {'title': 'En allvarligt skadad efter drunkningsolycka', 'summary': ''}, {'title': 'Barnhemmet har flytt från kriget – två gånger', 'summary': 'Söker skydd hos kloster – men oron är ständig: ”Varje stad kan bombas i morgon.”'}, {'title': 'Författaren Britt Arenander död', 'summary': ''}, {'title': 'Esbjörn Svensson-album släpps postumt', 'summary': ''}, {'title': '”Bioenergi bidrar inte till att träd försvinner ur skogen”', 'summary': ''}, {'title': 'Anhållen för misshandel av barn försatt på fri fot', 'summary': ''}, {'title': 'Nya och angelägna ambitioner på Röhsska museet', 'summary': ''}, {'title': 'Johnson pekas ut som ny Nato-chef', 'summary': 'Brittiska konservativa vill se skandalomsusade premiärministern på posten.'}, {'title': 'Brittisk pojke nekas livsuppehållande vård – mot familjens vilja', 'summary': ''}, {'title': 'Spotify lockar fler användare – med ökade förluster', 'summary': ''}, {'title': 'Därför spelar Sverige ingen bronsmatch i EM', 'summary': ''}, {'title': 'Dybala hyllades av fansen – trendade viralt', 'summary': ''}, {'title': 'Efter uppbrottet: ”Känner mig inte som Judas”', 'summary': ''}, {'title': 'Instagram: ”Kommer att bli mer videor”', 'summary': 'Efter kritik, bland annat från Kylie Jenner, om att appen blivit för lik Tiktok.'}, {'title': 'Tyska veteranen Popp glänser – i EM-debuten', 'summary': '31-åringen såg ut att missa sitt tredje raka EM: ”Folk hade räknat ut mig.”'}, {'title': 'Kvinna hittades död – nu åtalas maken', 'summary': 'Har erkänt att han orsakat kvinnans död.'}, {'title': '”Det handlar om politiskt maktspel”', 'summary': 'Så vässades turkiska terrorlagar mot regimkritiker.'}, {'title': 'Ännu oklart om Turkiet släpper fram Sverige', 'summary': 'Nytt utspel från turkiska utrikesministern i dag: ”Måste uppfylla sina löften.”'}, {'title': 'Kritik mot Sveriges Radios krishantering', 'summary': 'Nu höjs flera kritiska röster mot hur företagets ledning hanterat DN:s granskning.'}, {'title': 'Kvinna åtalas för mord i Upplands-Bro', 'summary': 'En kvinna i 50-årsåldern attackerades på parkeringsplats i april.'}, {'title': 'Omfattande förtryck mot kvinnor i Afghanistan', 'summary': 'Situationen förvärras för varje dag, konstaterar Amnesty i en ny rapport.'}, {'title': 'Fukt och stölder förstör konstskatt i Venezuela', 'summary': 'Det moderna konstmuseet i Caracas har blivit en symbol för en misslyckad revolution.'}, {'title': 'Nya studier: Härifrån kom coronaviruset', 'summary': 'Samstämmiga slutsatser publicerade – pekar ut marknaden i Wuhan.'}, {'title': 'Hugo Ewald: Anne-Marie Eklund Löwinder lyfter det oförändrade i it-världen', 'summary': '40 år senare är lösenord fortfarande det vanligaste sättet att skydda viktig data på.'}, {'title': 'Från guldfavoriter till en blytung finalmiss', 'summary': 'Covidsmäll, hemlighetsmakeri och besvikelse – så var Sveriges EM-resa.'}, {'title': 'R Kellys manager erkänner nya brott', 'summary': 'Dömdes nyligen för hot han riktat mot premiären av ”Surviving R Kelly”.'}, {'title': '”Master of puppets” har fått musikvideo', 'summary': ''}, {'title': 'Världsstjärnor stämda – anklagas för låtstöld', 'summary': 'Rapparna Megan Thee Stallion och Big Sean har inte svarat på stämningen.'}, {'title': '', 'summary': ''}, {'title': '• EM i dag: Självsäkert Tyskland ställs mot Frankrike', 'summary': ''}, {'title': 'Stockholmstestet – vad vet du om staden?', 'summary': ''}, {'title': 'Viljan att skänka pengar till Ukraina avtar', 'summary': 'Donatio ...
# 222
# [['Hällristningar skadade i Norge '], ['Hammarby stänger av Mohanad Jeahze '], ['Jan Scherman: SR:s Cilla Benkö fortsätter sitt arroganta korståg '], ['Cilla Benkö: Flera utgångspunkter i DN:s granskning är missvisande '], ['Coronahalt i avloppen ökar igen '], ['Lindelöf får konkurrens – mittback presenterad '], ['Neymar inför rätta – nio år efter övergången '], ['En allvarligt skadad efter drunkningsolycka '], ['Barnhemmet har flytt från kriget – två gånger Söker skydd hos kloster – men oron är ständig: ”Varje stad kan bombas i morgon.”'], ['Författaren Britt Arenander död '], ['Esbjörn Svensson-album släpps postumt '], ['”Bioenergi bidrar inte till att träd försvinner ur skogen” '], ['Anhållen för misshandel av barn försatt på fri fot '], ['Nya och angelägna ambitioner på Röhsska museet '], ['Johnson pekas ut som ny Nato-chef Brittiska konservativa vill se skandalomsusade premiärministern på posten.'], ['Brittisk pojke nekas livsuppehållande vård – mot familjens vilja '], ['Spotify lockar fler användare – med ökade förluster '], ['Därför spelar Sverige ingen bronsmatch i EM '], ['Dybala hyllades av fansen – trendade viralt '], ['Efter uppbrottet: ”Känner mig inte som Judas” '], ['Instagram: ”Kommer att bli mer videor” Efter kritik, bland annat från Kylie Jenner, om att appen blivit för lik Tiktok.'], ['Tyska veteranen Popp glänser – i EM-debuten 31-åringen såg ut att missa sitt tredje raka EM: ”Folk hade räknat ut mig.”'], ['Kvinna hittades död – nu åtalas maken Har erkänt att han orsakat kvinnans död.'], ['”Det handlar om politiskt maktspel” Så vässades turkiska terrorlagar mot regimkritiker.'], ['Ännu oklart om Turkiet släpper fram Sverige Nytt utspel från turkiska utrikesministern i dag: ”Måste uppfylla sina löften.”'], ['Kritik mot Sveriges Radios krishantering Nu höjs flera kritiska röster mot hur företagets ledning hanterat DN:s granskning.'], ['Kvinna åtalas för mord i Upplands-Bro En kvinna i 50-årsåldern attackerades på parkeringsplats i april.'], ['Omfattande förtryck mot kvinnor i Afghanistan Situationen förvärras för varje dag, konstaterar Amnesty i en ny rapport.'], ['Fukt och stölder förstör konstskatt i Venezuela Det moderna konstmuseet i Caracas har blivit en symbol för en misslyckad revolution.'], ['Nya studier: Härifrån kom coronaviruset Samstämmiga slutsatser publicerade – pekar ut marknaden i Wuhan.'], ['Hugo Ewald: Anne-Marie Eklund Löwinder lyfter det oförändrade i it-världen 40 år senare är lösenord fortfarande det vanligaste sättet att skydda viktig data på.'], ['Från guldfavoriter till en blytung finalmiss Covidsmäll, hemlighetsmakeri och besvikelse – så var Sveriges EM-resa.'], ['R Kellys manager erkänner nya brott Dömdes nyligen för hot han riktat mot premiären av ”Surviving R Kelly”.'], ['”Master of puppets” har fått musikvideo '], ['Världsstjärnor stämda – anklagas för låtstöld Rapparna Megan Thee Stallion och Big Sean har inte svarat på stämningen.'], [' '], ['• EM i dag: Självsäkert Tyskland ställs mot Frankrike '], ['Stockholmstestet – vad vet du om staden? '], ['Viljan att skänka pengar till Ukraina avtar Donationerna har minskat från rekordnivåer • Rädda barnen: ”Finns viss givartrötthet.”'], ['Johan Nilsson: Vuxna kan få en påfyllnadsdos i höst DN:s vetenskapsreporter svarar på frågor om corona.'], ['Fler på iva med corona – ”inte skenat iväg än” Expert: Kan bli värre i höst • Större ökning i andra länder.'], ['Ökad smitta i över hälften av regionerna Högre belastning på vården på grund av coronaviruset • Då erbjuds en fjärde dos.'], ['Ytterligare banker höjer räntan på bolånen Skandiabanken höjde räntan på sina bolån på morgonen • Så mycket dyrare blir ditt lån.'], ['Veteraner tvekar om fortsatt landslagsspel Hedvig Lindahl efter tunga förlusten: ”Räknar inte med fler matcher.”'], ['Asllani: ”Ska inte få rinna iväg så här” Sverige tangerade största förlusten någonsin.'], ['När porren tar över och sex blir ett missbruk Handlar inte i första hand om att skapa egen njutning • Kan pågå i timma ...
# 222

# %%
import feedparser
import sys
import pyodbc
import requests
import requests_toolbelt

RSS_URLS = ['http://www.dn.se/nyheter/m/rss/',
            'https://rss.aftonbladet.se/rss2/small/pages/sections/senastenytt/', 'https://feeds.expressen.se/nyheter/',
            'http://www.svd.se/?service=rss', 'http://api.sr.se/api/rss/program/83?format=145',
            'http://www.svt.se/nyheter/rss.xml'
              ]

posts = []

for url in RSS_URLS:
    posts.extend(feedparser.parse(url).entries)

# %%
def OnlyTitlesandSumaries():
    only_titles_and_summaries = []
    for x in posts:
        try:
            tempdict = {}
            tempdict["title"] = x["title"]
            tempdict["summary"] = x["summary"]
            only_titles_and_summaries.append(tempdict)
        except KeyError as ke:
            only_titles_and_summaries.append("") #replace the missing keys with empty space
    return only_titles_and_summaries

Only_the_titles_Summaries = OnlyTitlesandSumaries()

print(Only_the_titles_Summaries)
print(len(Only_the_titles_Summaries))
# Out:
# [{'title': 'Onödiga hälsotester av friska drabbar sjuka', 'summary': ''}, {'title': 'Shakira riskerar åtta års fängelse', 'summary': ''}, {'title': 'Anna Axfors: ”Det här är en nödlösning”', 'summary': ''}, {'title': 'OS-roddaren lägger av', 'summary': ''}, {'title': 'Covidutbrott efter dansbandsveckan har lett till kris i vården', 'summary': ''}, {'title': 'Döende pojkes familj går till FN i fall om livsuppehållande vård', 'summary': ''}, {'title': 'Instagram backar efter kritik mot förändrat flöde', 'summary': ''}, {'title': 'Ben Affleck återvänder som Batman', 'summary': ''}, {'title': 'Bombhot avblåst på Kastrup – terminal utrymdes', 'summary': ''}, {'title': 'Skärpt abortförbudsförslag föll i Indiana', 'summary': ''}, {'title': 'Migranter släpptes i havet – flera döda', 'summary': ''}, {'title': '”Brant nedgång” för reallönerna', 'summary': ''}, {'title': 'Jennifer Lopez bröllopsresa stoppade svenska boxarens drömfajt', 'summary': ''}, {'title': 'Man hittades död i Mölndal – mordmisstänkt anhållen', 'summary': ''}, {'title': '”Matrix”-skådespelare död', 'summary': ''}, {'title': 'Beyoncé anklagas för låtstöld', 'summary': ''}, {'title': 'Australien avvisar rykten om VM-flytt', 'summary': ''}, {'title': 'Ukrainare kanske stannar längre än väntat', 'summary': 'Migrationsverket: 7 miljarder mer behövs • ”Farhåga att resurser ska tas från andra”.'}, {'title': '”Viktigt att få välja kläder själv”', 'summary': 'Medarbetare på Stadsmissionen tänker på värdigheten för de skyddsbehövande.'}, {'title': 'Säverman: Hellre en snöboll i varje öra…', 'summary': ''}, {'title': 'Kajsa Haidl: Emma Schols berättelse om husbranden börjar brutalt', 'summary': 'Men när gripande scener ersätts av ord tappar Sommarpratet i intensitet.'}, {'title': 'Emanuel Örtengren: Höga bensinskatter har gynnat svenska bilister', 'summary': ''}, {'title': '', 'summary': ''}, {'title': 'Berlusconi är tillbaka i toppen – med nya laget', 'summary': 'Fem år efter att den kontroversielle 85-åringen sålt Milan har han skrivit ny historia.'}, {'title': 'Vinstförbud kan ge friskolor miljarder', 'summary': 'Bedömare reder ut om Socialdemokraternas vallöfte går att genomföra: ”Det är upplagt för tvist.”'}, {'title': 'Johan Croneman: S valfilmer lider av ett selektivt och uselt minne', 'summary': 'Palme lär rotera i graven över partiets u-sväng i Natofrågan.'}, {'title': 'Andreas Johansson Heinö: Marlon Brando var woke innan det blev coolt', 'summary': 'I dag finns åtminstone en förståelse för att rasismen finns. Att den är ett problem.'}, {'title': 'Hur ska jag hantera min besvikna svärmor?', 'summary': 'Söker konstant bekräftelse – familjen känner sig skuldbelagd • Psykoterapeuten ger råd.'}, {'title': 'Repris: Därför är dans så hälsosamt (även om du är oerfaren)', 'summary': ''}, {'title': 'Nutidstestet vecka 30 – har du hängt med?', 'summary': ''}, {'title': 'Trump står värd för LIV-touren: ”En guldrush”', 'summary': 'Expresidentens bana är skådeplats för saudisponsrade eventet • ”Vad de gör för golfen är fantastiskt.”'}, {'title': 'Märkliga spår på havsbotten förbryllar', 'summary': ''}, {'title': 'Här är soppan på kommunens krismeny', 'summary': 'Försvaret testar länets beredskap • ”Lite lyxigare variant” • Bara svenska råvaror.'}, {'title': 'Hien i fokus när Djurgården vann i Europakvalet', 'summary': 'Mittbacken i huvudroll när stockholmarna vann även returmatchen mot kroatiska Rijeka.'}, {'title': 'Martin Gelin: USA och Kina närmar sig en ny diplomatisk kris om Taiwan', 'summary': 'Xi Jinping anklagade Joe Biden för att ”leka med elden” i samtalet dem emellan på torsdagen.'}, {'title': 'Analytiker ser tidiga tecken på inflationstopp', 'summary': 'Nordea-chef: ”Här och nu är inflationen hög och den kommer också att förbli det i närtid.”'}, {'title': 'Näringslivet borde oroa sig mer för skolsystemet', 'summary': ''}, {'title': 'DN:s filmlista: Här är veckans 10 bästa filmer', 'summary': 'Generationsdramat ”Evolution” och japanska animesuccén ”Belle” nya på listan. ...
# 216

# %%
def TitleAndSummaryList():
    title_and_summary_list = []
    temp_and_summary_title_list = []
    for x in Only_the_titles_Summaries:
        for key in x:
            if 'title' == key:
                firstkey = x[key]
            if 'summary' == key:
                secondkey = x[key]
                temp_and_summary_title_list.append(firstkey + ' ' + secondkey)
        title_and_summary_list.append(temp_and_summary_title_list)
        temp_and_summary_title_list = []
    return title_and_summary_list

The_Title_Summary_List = TitleAndSummaryList()

# %%
print(The_Title_Summary_List)
print(len(The_Title_Summary_List))
# Out:
# [['Onödiga hälsotester av friska drabbar sjuka '], ['Shakira riskerar åtta års fängelse '], ['Anna Axfors: ”Det här är en nödlösning” '], ['OS-roddaren lägger av '], ['Covidutbrott efter dansbandsveckan har lett till kris i vården '], ['Döende pojkes familj går till FN i fall om livsuppehållande vård '], ['Instagram backar efter kritik mot förändrat flöde '], ['Ben Affleck återvänder som Batman '], ['Bombhot avblåst på Kastrup – terminal utrymdes '], ['Skärpt abortförbudsförslag föll i Indiana '], ['Migranter släpptes i havet – flera döda '], ['”Brant nedgång” för reallönerna '], ['Jennifer Lopez bröllopsresa stoppade svenska boxarens drömfajt '], ['Man hittades död i Mölndal – mordmisstänkt anhållen '], ['”Matrix”-skådespelare död '], ['Beyoncé anklagas för låtstöld '], ['Australien avvisar rykten om VM-flytt '], ['Ukrainare kanske stannar längre än väntat Migrationsverket: 7 miljarder mer behövs • ”Farhåga att resurser ska tas från andra”.'], ['”Viktigt att få välja kläder själv” Medarbetare på Stadsmissionen tänker på värdigheten för de skyddsbehövande.'], ['Säverman: Hellre en snöboll i varje öra… '], ['Kajsa Haidl: Emma Schols berättelse om husbranden börjar brutalt Men när gripande scener ersätts av ord tappar Sommarpratet i intensitet.'], ['Emanuel Örtengren: Höga bensinskatter har gynnat svenska bilister '], [' '], ['Berlusconi är tillbaka i toppen – med nya laget Fem år efter att den kontroversielle 85-åringen sålt Milan har han skrivit ny historia.'], ['Vinstförbud kan ge friskolor miljarder Bedömare reder ut om Socialdemokraternas vallöfte går att genomföra: ”Det är upplagt för tvist.”'], ['Johan Croneman: S valfilmer lider av ett selektivt och uselt minne Palme lär rotera i graven över partiets u-sväng i Natofrågan.'], ['Andreas Johansson Heinö: Marlon Brando var woke innan det blev coolt I dag finns åtminstone en förståelse för att rasismen finns. Att den är ett problem.'], ['Hur ska jag hantera min besvikna svärmor? Söker konstant bekräftelse – familjen känner sig skuldbelagd • Psykoterapeuten ger råd.'], ['Repris: Därför är dans så hälsosamt (även om du är oerfaren) '], ['Nutidstestet vecka 30 – har du hängt med? '], ['Trump står värd för LIV-touren: ”En guldrush” Expresidentens bana är skådeplats för saudisponsrade eventet • ”Vad de gör för golfen är fantastiskt.”'], ['Märkliga spår på havsbotten förbryllar '], ['Här är soppan på kommunens krismeny Försvaret testar länets beredskap • ”Lite lyxigare variant” • Bara svenska råvaror.'], ['Hien i fokus när Djurgården vann i Europakvalet Mittbacken i huvudroll när stockholmarna vann även returmatchen mot kroatiska Rijeka.'], ['Martin Gelin: USA och Kina närmar sig en ny diplomatisk kris om Taiwan Xi Jinping anklagade Joe Biden för att ”leka med elden” i samtalet dem emellan på torsdagen.'], ['Analytiker ser tidiga tecken på inflationstopp Nordea-chef: ”Här och nu är inflationen hög och den kommer också att förbli det i närtid.”'], ['Näringslivet borde oroa sig mer för skolsystemet '], ['DN:s filmlista: Här är veckans 10 bästa filmer Generationsdramat ”Evolution” och japanska animesuccén ”Belle” nya på listan.'], ['Brittisk tågstrejk leder till strid i Labour Samtidigt vill favoriten i konservativa Tories ledarstrid, Liz Truss, inskränka strejkrätten kraftigt.'], ['Här bor det allra flest hundraåringar i landet Kommun för kommun •\xa0Forskaren om faktorerna som gör att man lever länge.'], ['Han gör motstånd mot Putin – riskerar livstid Ilja Jasjin är en av de mest kända regimkritikerna som valde att stanna i Moskva • Väntar på rättegång.'], ['Tak rasade in – 65-årig man omkom Händelsen inträffade i kyrkbyn i Gammelstad i utkanten av Luleå.'], ['Intagna hade fest med sprit och lustgas ”Representerar inte vardagen i svensk kriminalvård” • Filmer från ”muckarfest” spreds i sociala medier.'], ['Trafikverket: Räkna med tågproblem i höst Under sommaren har många tåg blivit inställda och tågbolagen har svårt att planera långsiktigt.'], ['Så har Rolling Stones lyckats svänga ...
# 216

# %%
def PrintDeposit():
    newList= []
    for item in The_Title_Summary_List:
        for value in item:
            newList.append(value)
    return newList

# %%
print(PrintDeposit())
# Out:
# ['Onödiga hälsotester av friska drabbar sjuka ', 'Shakira riskerar åtta års fängelse ', 'Anna Axfors: ”Det här är en nödlösning” ', 'OS-roddaren lägger av ', 'Covidutbrott efter dansbandsveckan har lett till kris i vården ', 'Döende pojkes familj går till FN i fall om livsuppehållande vård ', 'Instagram backar efter kritik mot förändrat flöde ', 'Ben Affleck återvänder som Batman ', 'Bombhot avblåst på Kastrup – terminal utrymdes ', 'Skärpt abortförbudsförslag föll i Indiana ', 'Migranter släpptes i havet – flera döda ', '”Brant nedgång” för reallönerna ', 'Jennifer Lopez bröllopsresa stoppade svenska boxarens drömfajt ', 'Man hittades död i Mölndal – mordmisstänkt anhållen ', '”Matrix”-skådespelare död ', 'Beyoncé anklagas för låtstöld ', 'Australien avvisar rykten om VM-flytt ', 'Ukrainare kanske stannar längre än väntat Migrationsverket: 7 miljarder mer behövs • ”Farhåga att resurser ska tas från andra”.', '”Viktigt att få välja kläder själv” Medarbetare på Stadsmissionen tänker på värdigheten för de skyddsbehövande.', 'Säverman: Hellre en snöboll i varje öra… ', 'Kajsa Haidl: Emma Schols berättelse om husbranden börjar brutalt Men när gripande scener ersätts av ord tappar Sommarpratet i intensitet.', 'Emanuel Örtengren: Höga bensinskatter har gynnat svenska bilister ', ' ', 'Berlusconi är tillbaka i toppen – med nya laget Fem år efter att den kontroversielle 85-åringen sålt Milan har han skrivit ny historia.', 'Vinstförbud kan ge friskolor miljarder Bedömare reder ut om Socialdemokraternas vallöfte går att genomföra: ”Det är upplagt för tvist.”', 'Johan Croneman: S valfilmer lider av ett selektivt och uselt minne Palme lär rotera i graven över partiets u-sväng i Natofrågan.', 'Andreas Johansson Heinö: Marlon Brando var woke innan det blev coolt I dag finns åtminstone en förståelse för att rasismen finns. Att den är ett problem.', 'Hur ska jag hantera min besvikna svärmor? Söker konstant bekräftelse – familjen känner sig skuldbelagd • Psykoterapeuten ger råd.', 'Repris: Därför är dans så hälsosamt (även om du är oerfaren) ', 'Nutidstestet vecka 30 – har du hängt med? ', 'Trump står värd för LIV-touren: ”En guldrush” Expresidentens bana är skådeplats för saudisponsrade eventet • ”Vad de gör för golfen är fantastiskt.”', 'Märkliga spår på havsbotten förbryllar ', 'Här är soppan på kommunens krismeny Försvaret testar länets beredskap • ”Lite lyxigare variant” • Bara svenska råvaror.', 'Hien i fokus när Djurgården vann i Europakvalet Mittbacken i huvudroll när stockholmarna vann även returmatchen mot kroatiska Rijeka.', 'Martin Gelin: USA och Kina närmar sig en ny diplomatisk kris om Taiwan Xi Jinping anklagade Joe Biden för att ”leka med elden” i samtalet dem emellan på torsdagen.', 'Analytiker ser tidiga tecken på inflationstopp Nordea-chef: ”Här och nu är inflationen hög och den kommer också att förbli det i närtid.”', 'Näringslivet borde oroa sig mer för skolsystemet ', 'DN:s filmlista: Här är veckans 10 bästa filmer Generationsdramat ”Evolution” och japanska animesuccén ”Belle” nya på listan.', 'Brittisk tågstrejk leder till strid i Labour Samtidigt vill favoriten i konservativa Tories ledarstrid, Liz Truss, inskränka strejkrätten kraftigt.', 'Här bor det allra flest hundraåringar i landet Kommun för kommun •\xa0Forskaren om faktorerna som gör att man lever länge.', 'Han gör motstånd mot Putin – riskerar livstid Ilja Jasjin är en av de mest kända regimkritikerna som valde att stanna i Moskva • Väntar på rättegång.', 'Tak rasade in – 65-årig man omkom Händelsen inträffade i kyrkbyn i Gammelstad i utkanten av Luleå.', 'Intagna hade fest med sprit och lustgas ”Representerar inte vardagen i svensk kriminalvård” • Filmer från ”muckarfest” spreds i sociala medier.', 'Trafikverket: Räkna med tågproblem i höst Under sommaren har många tåg blivit inställda och tågbolagen har svårt att planera långsiktigt.', 'Så har Rolling Stones lyckats svänga i 60 år Martin Nyström djupdyker i ”rockens okända faktor” inför bandets Sverigebesök.', ...

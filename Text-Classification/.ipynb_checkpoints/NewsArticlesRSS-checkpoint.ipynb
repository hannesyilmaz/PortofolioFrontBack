# %%
import feedparser
import sys
import pyodbc
import requests
import requests_toolbelt
43/22:
RSS_URLS = ['http://www.dn.se/nyheter/m/rss/',
            'https://rss.aftonbladet.se/rss2/small/pages/sections/senastenytt/', 'https://feeds.expressen.se/nyheter/',
            'http://www.svd.se/?service=rss', 'http://api.sr.se/api/rss/program/83?format=145',
            'http://www.svt.se/nyheter/rss.xml'
              ]

posts = []

for url in RSS_URLS:
    posts.extend(feedparser.parse(url).entries)

def OnlyTitlesandSumaries():
    only_titles_and_summaries = []
    for x in posts:
        try:
            tempdict = {}
            tempdict["title"] = x["title"]
            tempdict["summary"] = x["summary"]
            only_titles_and_summaries.append(tempdict)
        except KeyError as ke:
            only_titles_and_summaries.append("") #replace the missing keys with empty space
    return only_titles_and_summaries

Only_the_titles_Summaries = OnlyTitlesandSumaries()

print(Only_the_titles_Summaries)
print(len(Only_the_titles_Summaries))

def TitleAndSummaryList():
    title_and_summary_list = []
    temp_and_summary_title_list = []
    for x in Only_the_titles_Summaries:
        for key in x:
            if 'title' == key:
                firstkey = x[key]
            if 'summary' == key:
                secondkey = x[key]
                temp_and_summary_title_list.append(firstkey + ' ' + secondkey)
        title_and_summary_list.append(temp_and_summary_title_list)
        temp_and_summary_title_list = []
    return title_and_summary_list

The_Title_Summary_List = TitleAndSummaryList()

print(The_Title_Summary_List)
print(len(The_Title_Summary_List))

def PrintDeposit():
    newList= []
    for item in The_Title_Summary_List:
        for value in item:
            newList.append(value)
    return newList

# %%
import feedparser
import sys
import pyodbc
import requests
import requests_toolbelt

RSS_URLS = ['http://www.dn.se/nyheter/m/rss/',
            'https://rss.aftonbladet.se/rss2/small/pages/sections/senastenytt/', 'https://feeds.expressen.se/nyheter/',
            'http://www.svd.se/?service=rss', 'http://api.sr.se/api/rss/program/83?format=145',
            'http://www.svt.se/nyheter/rss.xml'
              ]

posts = []

for url in RSS_URLS:
    posts.extend(feedparser.parse(url).entries)

# %%
def OnlyTitlesandSumaries():
    only_titles_and_summaries = []
    for x in posts:
        try:
            tempdict = {}
            tempdict["title"] = x["title"]
            tempdict["summary"] = x["summary"]
            only_titles_and_summaries.append(tempdict)
        except KeyError as ke:
            only_titles_and_summaries.append("") #replace the missing keys with empty space
    return only_titles_and_summaries

Only_the_titles_Summaries = OnlyTitlesandSumaries()

print(Only_the_titles_Summaries)
print(len(Only_the_titles_Summaries))
# Out:
# [{'title': 'Man hällde bensin på kvinna i Göteborg', 'summary': ''}, {'title': 'Sagolika vyer över grönt landskap längs Mosel', 'summary': 'Följ den snirklande floden, kantad av vinrankor. På klippor står slott och ruiner.'}, {'title': 'Vecka 27 i bilder – se världen genom DN-fotografernas ögon', 'summary': ''}, {'title': 'Coronasmitta i Nederländerna – dagen efter matchen mot Sverige', 'summary': ''}, {'title': 'Tre begärs häktade efter dödsskjutning i Länsmansgården', 'summary': ''}, {'title': 'Anders Lundin återvänder till Robinson', 'summary': ''}, {'title': 'Lotta Olsson tipsar: Här är 5 nya deckare man bör läsa', 'summary': ''}, {'title': 'Rörliga mittenväljarna som kan avgöra valet', 'summary': 'DN/Ipsos mäter partiernas potential • Riksdagsspärr blir stor utmaning för MP.'}, {'title': 'Massiv technoparad i Berlin', 'summary': ''}, {'title': 'Interna konflikter splittrar favorittippade Frankrike', 'summary': ''}, {'title': 'Gunna och Young Thug fortsatt häktade', 'summary': ''}, {'title': 'Enid Blytons Femböcker fyller åttio – men är evigt upproriska', 'summary': ''}, {'title': 'Över 57\xa0000 förarbevis för vattenskoter utfärdade', 'summary': ''}, {'title': 'Flera knivskurna i Göteborg – kopplas till gäng', 'summary': ''}, {'title': '14 ihjälskjutna på bar i Sydafrika i natt', 'summary': ''}, {'title': 'Depps nya film får premiär på franska Netflix', 'summary': ''}, {'title': 'Japan röstar i skuggan av mordet på Abe', 'summary': ''}, {'title': 'Öresundsbron öppen igen efter fläktfel', 'summary': ''}, {'title': 'Vart tog sportslighet vägen i gentlemannasporten tennis?', 'summary': ''}, {'title': 'Moa Malmqvist: Farah Abadi förvaltar tre generationers minnen av flykt', 'summary': ''}, {'title': 'Här är de viktigaste pensionsförändringarna', 'summary': ''}, {'title': 'Jessica: Köpa mensskydd var lika pinsamt som att köpa kondomer', 'summary': ''}, {'title': 'Moderaten säger nej till vinstdrivande friskolor', 'summary': 'Vill förbjuda dem • Nu har Robert Wenglén tröttnat på att bli ”rödsmetad” för sina åsikter.'}, {'title': 'Susanne Nyström: Därför kommer du inte att få din drömregering', 'summary': ''}, {'title': '• EM söndag 10 juli: Tess Olofsson dömer', 'summary': ''}, {'title': 'Lindahl om premiären: ”Energilöst”', 'summary': 'Fotbollsveteranerna besvikna efter krysset mot Nederländerna.'}, {'title': 'Så blev Henrik Persson Ekdahl en techmiljardär', 'summary': 'Berättar om resan dit, lyxlivet han lever och viljan att ge tillbaka • ”Försöker göra rätt.”'}, {'title': 'Vi har aldrig haft så mycket pengar som nu', 'summary': 'Konsumtionsforskaren: Hemmet har blivit en statusmarkör.'}, {'title': 'Emma Lukins: Premiären en besvikelse – men det ändrar ingenting', 'summary': ''}, {'title': 'Över 800 000 covidfall i Frankrike –\xa0på en vecka', 'summary': 'Antalet smittade av covid-19 ökar i Europa • 600 000 nya fall bekräftade i Italien.'}, {'title': 'Amber Heard skärper kraven om ny rättegång', 'summary': '”Nyupptäckta fakta” ska ogiltigförklara domslutet, enligt nya dokument.'}, {'title': 'Värsta bränderna på 15\xa0år i Amazonas', 'summary': 'Skövlingen i regnskogen ökar – och anlagda bränderna blir fler • Över 2\xa0000 bränder i juni.'}, {'title': 'Därför är lilla Ormön så viktig för Ryssland', 'summary': 'Ön utanför Ukrainas sydvästra hörn har blivit symbol för motståndet mot invasionen.'}, {'title': 'Boende i protest mot jakten på kobolt', 'summary': 'Metallen som är avgörande för elbilsbatterier är ett laddat ämne.'}, {'title': 'Osannolik målskytt – men bara kryss', 'summary': 'Sverige tog inte chansen. Poängtapp i EM-premiären trots ledning.'}, {'title': 'Tre döda i trafikolycka i Pajalatrakten', 'summary': 'Två personer har skadats i olyckan och förts till sjukhus.'}, {'title': 'Jätteräkor och tomater ska lösa beredskapen', 'summary': 'Projektledaren: Var tionde tomat ska komma härifrån • Hyllas av näringsministern.'}, {'title': 'Rysk hamburgerkedja har brist på pommes', 'summary': 'Före detta McDonalds-restauranger – ...
# 209

# %%
def TitleAndSummaryList():
    title_and_summary_list = []
    temp_and_summary_title_list = []
    for x in Only_the_titles_Summaries:
        for key in x:
            if 'title' == key:
                firstkey = x[key]
            if 'summary' == key:
                secondkey = x[key]
                temp_and_summary_title_list.append(firstkey + ' ' + secondkey)
        title_and_summary_list.append(temp_and_summary_title_list)
        temp_and_summary_title_list = []
    return title_and_summary_list

The_Title_Summary_List = TitleAndSummaryList()

# %%
print(The_Title_Summary_List)
print(len(The_Title_Summary_List))
# Out:
# [['Man hällde bensin på kvinna i Göteborg '], ['Sagolika vyer över grönt landskap längs Mosel Följ den snirklande floden, kantad av vinrankor. På klippor står slott och ruiner.'], ['Vecka 27 i bilder – se världen genom DN-fotografernas ögon '], ['Coronasmitta i Nederländerna – dagen efter matchen mot Sverige '], ['Tre begärs häktade efter dödsskjutning i Länsmansgården '], ['Anders Lundin återvänder till Robinson '], ['Lotta Olsson tipsar: Här är 5 nya deckare man bör läsa '], ['Rörliga mittenväljarna som kan avgöra valet DN/Ipsos mäter partiernas potential • Riksdagsspärr blir stor utmaning för MP.'], ['Massiv technoparad i Berlin '], ['Interna konflikter splittrar favorittippade Frankrike '], ['Gunna och Young Thug fortsatt häktade '], ['Enid Blytons Femböcker fyller åttio – men är evigt upproriska '], ['Över 57\xa0000 förarbevis för vattenskoter utfärdade '], ['Flera knivskurna i Göteborg – kopplas till gäng '], ['14 ihjälskjutna på bar i Sydafrika i natt '], ['Depps nya film får premiär på franska Netflix '], ['Japan röstar i skuggan av mordet på Abe '], ['Öresundsbron öppen igen efter fläktfel '], ['Vart tog sportslighet vägen i gentlemannasporten tennis? '], ['Moa Malmqvist: Farah Abadi förvaltar tre generationers minnen av flykt '], ['Här är de viktigaste pensionsförändringarna '], ['Jessica: Köpa mensskydd var lika pinsamt som att köpa kondomer '], ['Moderaten säger nej till vinstdrivande friskolor Vill förbjuda dem • Nu har Robert Wenglén tröttnat på att bli ”rödsmetad” för sina åsikter.'], ['Susanne Nyström: Därför kommer du inte att få din drömregering '], ['• EM söndag 10 juli: Tess Olofsson dömer '], ['Lindahl om premiären: ”Energilöst” Fotbollsveteranerna besvikna efter krysset mot Nederländerna.'], ['Så blev Henrik Persson Ekdahl en techmiljardär Berättar om resan dit, lyxlivet han lever och viljan att ge tillbaka • ”Försöker göra rätt.”'], ['Vi har aldrig haft så mycket pengar som nu Konsumtionsforskaren: Hemmet har blivit en statusmarkör.'], ['Emma Lukins: Premiären en besvikelse – men det ändrar ingenting '], ['Över 800 000 covidfall i Frankrike –\xa0på en vecka Antalet smittade av covid-19 ökar i Europa • 600 000 nya fall bekräftade i Italien.'], ['Amber Heard skärper kraven om ny rättegång ”Nyupptäckta fakta” ska ogiltigförklara domslutet, enligt nya dokument.'], ['Värsta bränderna på 15\xa0år i Amazonas Skövlingen i regnskogen ökar – och anlagda bränderna blir fler • Över 2\xa0000 bränder i juni.'], ['Därför är lilla Ormön så viktig för Ryssland Ön utanför Ukrainas sydvästra hörn har blivit symbol för motståndet mot invasionen.'], ['Boende i protest mot jakten på kobolt Metallen som är avgörande för elbilsbatterier är ett laddat ämne.'], ['Osannolik målskytt – men bara kryss Sverige tog inte chansen. Poängtapp i EM-premiären trots ledning.'], ['Tre döda i trafikolycka i Pajalatrakten Två personer har skadats i olyckan och förts till sjukhus.'], ['Jätteräkor och tomater ska lösa beredskapen Projektledaren: Var tionde tomat ska komma härifrån • Hyllas av näringsministern.'], ['Rysk hamburgerkedja har brist på pommes Före detta McDonalds-restauranger – hänvisar till dåliga skördar och exportstopp.'], ['Svensken skriver nytt jättekontrakt '], ['Studier: Tydlig vinst med höghastighetståg Enligt Trafikverket innebär satsningen stor förlust – men två studier pekar på motsatsen.'], ['Flera ministrar vill ta över Johnsons jobb Förhandsfavoriten Ben Wallace, försvarsminister, önskar dock inte bli ny premiärminister.'], ['Tusentals strandsatta när charterflyg ställs in Cirka 700 resenärer fick sina flyg till Sverige inställda under lördagen.'], ['Fackförbund på SAS provoceras av strejken Andra fackförbund i flygbolaget kritiserar pilotfacket: ”Provocerande.”'], ['Humanitär katastrof nära i Sievjerodonetsk Civilbefolkningen uppmanas lämna ryskockuperade städer i sydöstra Ukraina.'], ['Kerstin Gezelius: Jag ångrar mig – Benedict Cumberbatch var helt fel för rollen Filmkritikern Kerstin Gezelius om eftertankens kranka b ...
# 209

# %%
def PrintDeposit():
    newList= []
    for item in The_Title_Summary_List:
        for value in item:
            newList.append(value)
    return newList

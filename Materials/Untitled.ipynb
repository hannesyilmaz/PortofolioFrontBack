# %%
import feedparser
import sys
import pyodbc
import requests
import requests_toolbelt

# %%
RSS_URLS = ['http://www.dn.se/nyheter/m/rss/',
            'https://rss.aftonbladet.se/rss2/small/pages/sections/senastenytt/', 'https://feeds.expressen.se/nyheter/',
            'http://www.svd.se/?service=rss', 'http://api.sr.se/api/rss/program/83?format=145',
            'http://www.svt.se/nyheter/rss.xml'
              ]

posts = []

for url in RSS_URLS:
    posts.extend(feedparser.parse(url).entries)

# %%
def OnlyTitlesandSumaries():
    only_titles_and_summaries = []
    for x in posts:
        try:
            tempdict = {}
            tempdict["title"] = x["title"]
            tempdict["summary"] = x["summary"]
            only_titles_and_summaries.append(tempdict)
        except KeyError as ke:
            only_titles_and_summaries.append("") #replace the missing keys with empty space
    return only_titles_and_summaries

Only_the_titles_Summaries = OnlyTitlesandSumaries()

# %%
print(Only_the_titles_Summaries)
print(len(Only_the_titles_Summaries))
# Out:
# [{'title': 'Ståhls tränare utbränd – missar VM', 'summary': ''}, {'title': 'Ivorian ersätter Haaland i Dortmund', 'summary': ''}, {'title': 'Nadal till semifinal – efter stor dramatik', 'summary': ''}, {'title': 'En av Stockholms mest kända kyrkor hotas av rivning', 'summary': ''}, {'title': 'Undersökning: Allt fler svenskar har kontanter på sig', 'summary': ''}, {'title': 'Här är de bästa vägkrogarna i Sverige', 'summary': 'Kan vara svårt att hitta bra mat längs de stora vägarna • Sju ställen med det lilla extra.'}, {'title': '”Känns väldigt obehagligt, jag är skärrad”', 'summary': 'Marion Wegerstedt besökte politikerveckan för första gången – blev vittne till knivdådet.'}, {'title': 'Gränslös, del 12 av 50', 'summary': ''}, {'title': 'Uppgifter: Ministrar pressar Johnson att avgå', 'summary': 'Sitter i möte med premiärministern för att få honom att lämna sitt uppdrag, rapporterar BBC.'}, {'title': 'Ingen final för Sverige i U19-EM', 'summary': ''}, {'title': 'Malmö säljer Ahmedhodzic', 'summary': ''}, {'title': 'Offret vågade vittna – gängledare dömdes till 12 års fängelse', 'summary': ''}, {'title': 'Kyrgios enkelt till semifinal – trots anklagelserna', 'summary': ''}, {'title': '”Tunna blå linjen 2” premiärvisas på Way out west', 'summary': ''}, {'title': 'S i Stockholm klandrar M efter Sös-kritiken', 'summary': ''}, {'title': 'Michail Sjisjkin: Putin använder kulturen som stridskamouflage', 'summary': ''}, {'title': 'Erik de la Reguera: Som om en anständighetens gräns passerats i partiet', 'summary': ''}, {'title': 'Lars tacklade omkull misstänkte knivmannen', 'summary': '”Att någon förstör Almedalen gör mig förbannad.”'}, {'title': 'Malmö Pride invigt –\xa0på vatten', 'summary': ''}, {'title': 'Bryggbasens jobb: Vakta så att ingen försvinner under ytan', 'summary': ''}, {'title': '”Moderaternas plan för kärnkraft hänger inte ihop”', 'summary': 'Fyra energiexperter: M gynnar ny kärnkraft på vindkraftens bekostnad. Med tanke på industrins behov av ny elproduktion redan till 2030 är det mycket förvånande.'}, {'title': 'Erik Helmerson: Dådet är en tragedi – och en mardröm för Almedalen', 'summary': ''}, {'title': '', 'summary': ''}, {'title': 'Använde fel skor – får inte tävla i VM-längden', 'summary': ''}, {'title': 'Ewa Stenberg: Jimmie Åkesson har en ny roll i Almedalen', 'summary': 'Kommer för första gången till Almedalsveckan som en lagmedlem.'}, {'title': 'Peterson vände och vann i Båstad', 'summary': 'Men svensk damtennis andra affischnamn, Mirjam Björklund, slogs ut.'}, {'title': 'Halep till semi: ”Är väldigt känslosam”', 'summary': 'Vann Wimbledon för tre år sedan men har haft flera tröga år..'}, {'title': 'Kärnkraft och gas ska räknas som hållbar energi', 'summary': 'Kontroversiellt beslut i EU-parlamentet • C-ledamot: Ett historiskt svek.'}, {'title': 'Rivalerna lider med skadade stjärnan', 'summary': 'Spaniens Alexia Putellas, prisad som bäst i världen, kommer inte kunna spela en enda EM-minut.'}, {'title': 'England perfekt arena för att lyfta damfotboll', 'summary': 'Ett EM i ”fotbollens hemland” har symbolisk betydelse: ”Känns som att det inte kan gå fel.”'}, {'title': 'BBC tar bort intervju med ”Sabaya”-regissör', 'summary': 'Dokumentären som utspelar sig i flyktingläger i Syrien har kritiserats.'}, {'title': 'Ilska efter att HBO tagit bort nordiska serier', 'summary': '”En rullgardin som dragits ned”, säger producent bakom ”Lust”.'}, {'title': 'Danska filmskapare förhandlar med Netflix', 'summary': ''}, {'title': 'Kvinnan som knivhöggs i Visby har avlidit', 'summary': '33-åring anhållen misstänkt för mord • Polisen: Hotbilden mot Almedalen oförändrad.'}, {'title': 'Många till sjukhus i ovanligt varmt Japan', 'summary': 'Rekordhöga temperaturer i landet under juni månad • 17 personer avled på sjukhus.'}, {'title': 'Omdiskuterat köp av Engelska skolan avblåst', 'summary': 'Skolledningen går inte vidare med fastighetsköpet i Gubbängen.'}, {'title': 'En person skjuten av polis i Hudiksvall', 'summary': 'Skedde i  ...
# 226

# %%
def TitleAndSummaryList():
    title_and_summary_list = []
    temp_and_summary_title_list = []
    for x in Only_the_titles_Summaries:
        for key in x:
            if 'title' == key:
                firstkey = x[key]
            if 'summary' == key:
                secondkey = x[key]
                temp_and_summary_title_list.append(firstkey + ' ' + secondkey)
        title_and_summary_list.append(temp_and_summary_title_list)
        temp_and_summary_title_list = []
    return title_and_summary_list

The_Title_Summary_List = TitleAndSummaryList()

# %%
print(The_Title_Summary_List)
print(len(The_Title_Summary_List))
# Out:
# [['Ståhls tränare utbränd – missar VM '], ['Ivorian ersätter Haaland i Dortmund '], ['Nadal till semifinal – efter stor dramatik '], ['En av Stockholms mest kända kyrkor hotas av rivning '], ['Undersökning: Allt fler svenskar har kontanter på sig '], ['Här är de bästa vägkrogarna i Sverige Kan vara svårt att hitta bra mat längs de stora vägarna • Sju ställen med det lilla extra.'], ['”Känns väldigt obehagligt, jag är skärrad” Marion Wegerstedt besökte politikerveckan för första gången – blev vittne till knivdådet.'], ['Gränslös, del 12 av 50 '], ['Uppgifter: Ministrar pressar Johnson att avgå Sitter i möte med premiärministern för att få honom att lämna sitt uppdrag, rapporterar BBC.'], ['Ingen final för Sverige i U19-EM '], ['Malmö säljer Ahmedhodzic '], ['Offret vågade vittna – gängledare dömdes till 12 års fängelse '], ['Kyrgios enkelt till semifinal – trots anklagelserna '], ['”Tunna blå linjen 2” premiärvisas på Way out west '], ['S i Stockholm klandrar M efter Sös-kritiken '], ['Michail Sjisjkin: Putin använder kulturen som stridskamouflage '], ['Erik de la Reguera: Som om en anständighetens gräns passerats i partiet '], ['Lars tacklade omkull misstänkte knivmannen ”Att någon förstör Almedalen gör mig förbannad.”'], ['Malmö Pride invigt –\xa0på vatten '], ['Bryggbasens jobb: Vakta så att ingen försvinner under ytan '], ['”Moderaternas plan för kärnkraft hänger inte ihop” Fyra energiexperter: M gynnar ny kärnkraft på vindkraftens bekostnad. Med tanke på industrins behov av ny elproduktion redan till 2030 är det mycket förvånande.'], ['Erik Helmerson: Dådet är en tragedi – och en mardröm för Almedalen '], [' '], ['Använde fel skor – får inte tävla i VM-längden '], ['Ewa Stenberg: Jimmie Åkesson har en ny roll i Almedalen Kommer för första gången till Almedalsveckan som en lagmedlem.'], ['Peterson vände och vann i Båstad Men svensk damtennis andra affischnamn, Mirjam Björklund, slogs ut.'], ['Halep till semi: ”Är väldigt känslosam” Vann Wimbledon för tre år sedan men har haft flera tröga år..'], ['Kärnkraft och gas ska räknas som hållbar energi Kontroversiellt beslut i EU-parlamentet • C-ledamot: Ett historiskt svek.'], ['Rivalerna lider med skadade stjärnan Spaniens Alexia Putellas, prisad som bäst i världen, kommer inte kunna spela en enda EM-minut.'], ['England perfekt arena för att lyfta damfotboll Ett EM i ”fotbollens hemland” har symbolisk betydelse: ”Känns som att det inte kan gå fel.”'], ['BBC tar bort intervju med ”Sabaya”-regissör Dokumentären som utspelar sig i flyktingläger i Syrien har kritiserats.'], ['Ilska efter att HBO tagit bort nordiska serier ”En rullgardin som dragits ned”, säger producent bakom ”Lust”.'], ['Danska filmskapare förhandlar med Netflix '], ['Kvinnan som knivhöggs i Visby har avlidit 33-åring anhållen misstänkt för mord • Polisen: Hotbilden mot Almedalen oförändrad.'], ['Många till sjukhus i ovanligt varmt Japan Rekordhöga temperaturer i landet under juni månad • 17 personer avled på sjukhus.'], ['Omdiskuterat köp av Engelska skolan avblåst Skolledningen går inte vidare med fastighetsköpet i Gubbängen.'], ['En person skjuten av polis i Hudiksvall Skedde i samband med ingripande – skadeläget oklart.'], ['Uppdaterat vaccin efter sommaren Vaccinsamordnaren: Vi har köpt in volymer som räcker till hela befolkningen.'], ['Nye statsepidemiologen: ”Inte sett detta tidigare” Smittspridningen av covid-19 ökar – tvärtemot tidigare somrar under pandemin.'], ['Blackstenius hoppfull om spel: ”Men läget inte optimalt” Stjärna med skadekänning inför lördagens svenska EM-premiär.'], ['Alison Krauss och Robert Plant skapar musikmagi på Dalhalla Storheten blir helt tydlig först när man ser och hör dem live, skriver DN:s recensent.'], ['Tre anhållna efter misstänkt kidnappning i Alingsås Flera blev vittnen till hur en man drogs in i en stadsjeep – som sedan lämnade platsen.'], ['FI granskar Swedbanks kontohaveri Korrekta saldon på kundernas konton försvann.'], ['Suggestiv sommarutställning på Alma Löv museum B ...
# 226

# %%
def PrintDeposit():
    newList= []
    for item in The_Title_Summary_List:
        for value in item:
            newList.append(value)
    return newList



Old_List = PrintDeposit()

# %%
print(Old_List)
# Out:
# ['Ståhls tränare utbränd – missar VM ', 'Ivorian ersätter Haaland i Dortmund ', 'Nadal till semifinal – efter stor dramatik ', 'En av Stockholms mest kända kyrkor hotas av rivning ', 'Undersökning: Allt fler svenskar har kontanter på sig ', 'Här är de bästa vägkrogarna i Sverige Kan vara svårt att hitta bra mat längs de stora vägarna • Sju ställen med det lilla extra.', '”Känns väldigt obehagligt, jag är skärrad” Marion Wegerstedt besökte politikerveckan för första gången – blev vittne till knivdådet.', 'Gränslös, del 12 av 50 ', 'Uppgifter: Ministrar pressar Johnson att avgå Sitter i möte med premiärministern för att få honom att lämna sitt uppdrag, rapporterar BBC.', 'Ingen final för Sverige i U19-EM ', 'Malmö säljer Ahmedhodzic ', 'Offret vågade vittna – gängledare dömdes till 12 års fängelse ', 'Kyrgios enkelt till semifinal – trots anklagelserna ', '”Tunna blå linjen 2” premiärvisas på Way out west ', 'S i Stockholm klandrar M efter Sös-kritiken ', 'Michail Sjisjkin: Putin använder kulturen som stridskamouflage ', 'Erik de la Reguera: Som om en anständighetens gräns passerats i partiet ', 'Lars tacklade omkull misstänkte knivmannen ”Att någon förstör Almedalen gör mig förbannad.”', 'Malmö Pride invigt –\xa0på vatten ', 'Bryggbasens jobb: Vakta så att ingen försvinner under ytan ', '”Moderaternas plan för kärnkraft hänger inte ihop” Fyra energiexperter: M gynnar ny kärnkraft på vindkraftens bekostnad. Med tanke på industrins behov av ny elproduktion redan till 2030 är det mycket förvånande.', 'Erik Helmerson: Dådet är en tragedi – och en mardröm för Almedalen ', ' ', 'Använde fel skor – får inte tävla i VM-längden ', 'Ewa Stenberg: Jimmie Åkesson har en ny roll i Almedalen Kommer för första gången till Almedalsveckan som en lagmedlem.', 'Peterson vände och vann i Båstad Men svensk damtennis andra affischnamn, Mirjam Björklund, slogs ut.', 'Halep till semi: ”Är väldigt känslosam” Vann Wimbledon för tre år sedan men har haft flera tröga år..', 'Kärnkraft och gas ska räknas som hållbar energi Kontroversiellt beslut i EU-parlamentet • C-ledamot: Ett historiskt svek.', 'Rivalerna lider med skadade stjärnan Spaniens Alexia Putellas, prisad som bäst i världen, kommer inte kunna spela en enda EM-minut.', 'England perfekt arena för att lyfta damfotboll Ett EM i ”fotbollens hemland” har symbolisk betydelse: ”Känns som att det inte kan gå fel.”', 'BBC tar bort intervju med ”Sabaya”-regissör Dokumentären som utspelar sig i flyktingläger i Syrien har kritiserats.', 'Ilska efter att HBO tagit bort nordiska serier ”En rullgardin som dragits ned”, säger producent bakom ”Lust”.', 'Danska filmskapare förhandlar med Netflix ', 'Kvinnan som knivhöggs i Visby har avlidit 33-åring anhållen misstänkt för mord • Polisen: Hotbilden mot Almedalen oförändrad.', 'Många till sjukhus i ovanligt varmt Japan Rekordhöga temperaturer i landet under juni månad • 17 personer avled på sjukhus.', 'Omdiskuterat köp av Engelska skolan avblåst Skolledningen går inte vidare med fastighetsköpet i Gubbängen.', 'En person skjuten av polis i Hudiksvall Skedde i samband med ingripande – skadeläget oklart.', 'Uppdaterat vaccin efter sommaren Vaccinsamordnaren: Vi har köpt in volymer som räcker till hela befolkningen.', 'Nye statsepidemiologen: ”Inte sett detta tidigare” Smittspridningen av covid-19 ökar – tvärtemot tidigare somrar under pandemin.', 'Blackstenius hoppfull om spel: ”Men läget inte optimalt” Stjärna med skadekänning inför lördagens svenska EM-premiär.', 'Alison Krauss och Robert Plant skapar musikmagi på Dalhalla Storheten blir helt tydlig först när man ser och hör dem live, skriver DN:s recensent.', 'Tre anhållna efter misstänkt kidnappning i Alingsås Flera blev vittnen till hur en man drogs in i en stadsjeep – som sedan lämnade platsen.', 'FI granskar Swedbanks kontohaveri Korrekta saldon på kundernas konton försvann.', 'Suggestiv sommarutställning på Alma Löv museum Birgitta Rubin ser en rad starka och sällsamma verk i en särpräglad miljö.', '• Inga för ...

# %%
def GetHeading():
    newerList = []
    for i in oldList:
        input_dict = {"Heading":'"'+i+'"'}
        newerList.append(input_dict)
    return newerList


Only_Heading = GetHeading()

# %%
print(Only_heading)
# Out:
# [{'Heading': '"Ståhls tränare utbränd – missar VM "'}, {'Heading': '"Ivorian ersätter Haaland i Dortmund "'}, {'Heading': '"Nadal till semifinal – efter stor dramatik "'}, {'Heading': '"En av Stockholms mest kända kyrkor hotas av rivning "'}, {'Heading': '"Undersökning: Allt fler svenskar har kontanter på sig "'}, {'Heading': '"Här är de bästa vägkrogarna i Sverige Kan vara svårt att hitta bra mat längs de stora vägarna • Sju ställen med det lilla extra."'}, {'Heading': '"”Känns väldigt obehagligt, jag är skärrad” Marion Wegerstedt besökte politikerveckan för första gången – blev vittne till knivdådet."'}, {'Heading': '"Gränslös, del 12 av 50 "'}, {'Heading': '"Uppgifter: Ministrar pressar Johnson att avgå Sitter i möte med premiärministern för att få honom att lämna sitt uppdrag, rapporterar BBC."'}, {'Heading': '"Ingen final för Sverige i U19-EM "'}, {'Heading': '"Malmö säljer Ahmedhodzic "'}, {'Heading': '"Offret vågade vittna – gängledare dömdes till 12 års fängelse "'}, {'Heading': '"Kyrgios enkelt till semifinal – trots anklagelserna "'}, {'Heading': '"”Tunna blå linjen 2” premiärvisas på Way out west "'}, {'Heading': '"S i Stockholm klandrar M efter Sös-kritiken "'}, {'Heading': '"Michail Sjisjkin: Putin använder kulturen som stridskamouflage "'}, {'Heading': '"Erik de la Reguera: Som om en anständighetens gräns passerats i partiet "'}, {'Heading': '"Lars tacklade omkull misstänkte knivmannen ”Att någon förstör Almedalen gör mig förbannad.”"'}, {'Heading': '"Malmö Pride invigt –\xa0på vatten "'}, {'Heading': '"Bryggbasens jobb: Vakta så att ingen försvinner under ytan "'}, {'Heading': '"”Moderaternas plan för kärnkraft hänger inte ihop” Fyra energiexperter: M gynnar ny kärnkraft på vindkraftens bekostnad. Med tanke på industrins behov av ny elproduktion redan till 2030 är det mycket förvånande."'}, {'Heading': '"Erik Helmerson: Dådet är en tragedi – och en mardröm för Almedalen "'}, {'Heading': '" "'}, {'Heading': '"Använde fel skor – får inte tävla i VM-längden "'}, {'Heading': '"Ewa Stenberg: Jimmie Åkesson har en ny roll i Almedalen Kommer för första gången till Almedalsveckan som en lagmedlem."'}, {'Heading': '"Peterson vände och vann i Båstad Men svensk damtennis andra affischnamn, Mirjam Björklund, slogs ut."'}, {'Heading': '"Halep till semi: ”Är väldigt känslosam” Vann Wimbledon för tre år sedan men har haft flera tröga år.."'}, {'Heading': '"Kärnkraft och gas ska räknas som hållbar energi Kontroversiellt beslut i EU-parlamentet • C-ledamot: Ett historiskt svek."'}, {'Heading': '"Rivalerna lider med skadade stjärnan Spaniens Alexia Putellas, prisad som bäst i världen, kommer inte kunna spela en enda EM-minut."'}, {'Heading': '"England perfekt arena för att lyfta damfotboll Ett EM i ”fotbollens hemland” har symbolisk betydelse: ”Känns som att det inte kan gå fel.”"'}, {'Heading': '"BBC tar bort intervju med ”Sabaya”-regissör Dokumentären som utspelar sig i flyktingläger i Syrien har kritiserats."'}, {'Heading': '"Ilska efter att HBO tagit bort nordiska serier ”En rullgardin som dragits ned”, säger producent bakom ”Lust”."'}, {'Heading': '"Danska filmskapare förhandlar med Netflix "'}, {'Heading': '"Kvinnan som knivhöggs i Visby har avlidit 33-åring anhållen misstänkt för mord • Polisen: Hotbilden mot Almedalen oförändrad."'}, {'Heading': '"Många till sjukhus i ovanligt varmt Japan Rekordhöga temperaturer i landet under juni månad • 17 personer avled på sjukhus."'}, {'Heading': '"Omdiskuterat köp av Engelska skolan avblåst Skolledningen går inte vidare med fastighetsköpet i Gubbängen."'}, {'Heading': '"En person skjuten av polis i Hudiksvall Skedde i samband med ingripande – skadeläget oklart."'}, {'Heading': '"Uppdaterat vaccin efter sommaren Vaccinsamordnaren: Vi har köpt in volymer som räcker till hela befolkningen."'}, {'Heading': '"Nye statsepidemiologen: ”Inte sett detta tidigare” Smittspridningen av covid-19 ökar – tvärtemot tidigare somrar under pandemin."'}, {'Heading': '"Blackstenius hoppfull om spel: ”Me ...
